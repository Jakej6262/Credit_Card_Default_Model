# %% [markdown]
# 661 Final Project
# Group number 1: Ayan Sengupta, Gabe Schulefand, Jake Jackson

# %% [markdown]
# 1. Importing Libraries and Downloading data sets

# %%
# import libraries
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
# import data from air bnb insider into data frames

## San Diego Listings Data (detailed)
san_diego_listings = pd.read_csv('https://data.insideairbnb.com/united-states/ca/san-diego/2024-12-23/data/listings.csv.gz', compression='gzip')
## San Diego Reviews Data (detailed)
san_diego_reviews = pd.read_csv('https://data.insideairbnb.com/united-states/ca/san-diego/2024-12-23/data/reviews.csv.gz', compression='gzip')

# %% [markdown]
# 2. Exploring the Data and Data Cleaning
#
#    link to the data dictionary to understand each column of the listings data: https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit?gid=1322284596#gid=1322284596
#
#    link to data dictionary to understand each column of the reviews data: https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit?gid=0#gid=0

# %%
## exploring the listings data
print(san_diego_listings.info())
print(san_diego_listings.head())
print(san_diego_listings.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12844 entries, 0 to 12843
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            12844 non-null  int64
#  1   listing_url                                   12844 non-null  object
#  2   scrape_id                                     12844 non-null  int64
#  3   last_scraped                                  12844 non-null  object
#  4   source                                        12844 non-null  object
#  5   name                                          12844 non-null  object
#  6   description                                   12638 non-null  object
#  7   neighborhood_overview                         8046 non-null   object
#  8   picture_url                                   12844 non-null  object
#  9   host_id                                       12844 non-null  int64
#  10  host_url                                      12844 non-null  object
#  11  host_name                                     12844 non-null  object
#  12  host_since                                    12844 non-null  object
#  13  host_location                                 10156 non-null  object
#  14  host_about                                    8070 non-null   object
#  15  host_response_time                            11383 non-null  object
#  16  host_response_rate                            11383 non-null  object
#  17  host_acceptance_rate                          11903 non-null  object
#  18  host_is_superhost                             12421 non-null  object
#  19  host_thumbnail_url                            12844 non-null  object
#  20  host_picture_url                              12844 non-null  object
#  21  host_neighbourhood                            12205 non-null  object
#  22  host_listings_count                           12844 non-null  int64
#  23  host_total_listings_count                     12844 non-null  int64
#  24  host_verifications                            12844 non-null  object
#  25  host_has_profile_pic                          12844 non-null  object
#  26  host_identity_verified                        12844 non-null  object
#  27  neighbourhood                                 8046 non-null   object
#  28  neighbourhood_cleansed                        12844 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      12844 non-null  float64
#  31  longitude                                     12844 non-null  float64
#  32  property_type                                 12844 non-null  object
#  33  room_type                                     12844 non-null  object
#  34  accommodates                                  12844 non-null  int64
#  35  bathrooms                                     11660 non-null  float64
#  36  bathrooms_text                                12843 non-null  object
#  37  bedrooms                                      12640 non-null  float64
#  38  beds                                          11620 non-null  float64
#  39  amenities                                     12844 non-null  object
#  40  price                                         11660 non-null  object
#  41  minimum_nights                                12844 non-null  int64
#  42  maximum_nights                                12844 non-null  int64
#  43  minimum_minimum_nights                        12843 non-null  float64
#  44  maximum_minimum_nights                        12843 non-null  float64
#  45  minimum_maximum_nights                        12843 non-null  float64
#  46  maximum_maximum_nights                        12843 non-null  float64
#  47  minimum_nights_avg_ntm                        12843 non-null  float64
#  48  maximum_nights_avg_ntm                        12843 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              12755 non-null  object
#  51  availability_30                               12844 non-null  int64
#  52  availability_60                               12844 non-null  int64
#  53  availability_90                               12844 non-null  int64
#  54  availability_365                              12844 non-null  int64
#  55  calendar_last_scraped                         12844 non-null  object
#  56  number_of_reviews                             12844 non-null  int64
#  57  number_of_reviews_ltm                         12844 non-null  int64
#  58  number_of_reviews_l30d                        12844 non-null  int64
#  59  first_review                                  10638 non-null  object
#  60  last_review                                   10638 non-null  object
#  61  review_scores_rating                          10638 non-null  float64
#  62  review_scores_accuracy                        10638 non-null  float64
#  63  review_scores_cleanliness                     10638 non-null  float64
#  64  review_scores_checkin                         10638 non-null  float64
#  65  review_scores_communication                   10638 non-null  float64
#  66  review_scores_location                        10638 non-null  float64
#  67  review_scores_value                           10638 non-null  float64
#  68  license                                       10133 non-null  object
#  69  instant_bookable                              12844 non-null  object
#  70  calculated_host_listings_count                12844 non-null  int64
#  71  calculated_host_listings_count_entire_homes   12844 non-null  int64
#  72  calculated_host_listings_count_private_rooms  12844 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   12844 non-null  int64
#  74  reviews_per_month                             10638 non-null  float64
# dtypes: float64(21), int64(19), object(35)
# memory usage: 7.3+ MB
# None
#       id                         listing_url       scrape_id last_scraped  \
# 0      6      https://www.airbnb.com/rooms/6  20241223022521   2024-12-23
# 1  12447  https://www.airbnb.com/rooms/12447  20241223022521   2024-12-23
# 2  29967  https://www.airbnb.com/rooms/29967  20241223022521   2024-12-23
# 3  54001  https://www.airbnb.com/rooms/54001  20241223022521   2024-12-23
# 4  62274  https://www.airbnb.com/rooms/62274  20241223022521   2024-12-23
#
#         source                                             name  \
# 0  city scrape  North Park Craftsmen House * Great for Families
# 1  city scrape                     Cozy Pacific Beach Hideaway!
# 2  city scrape                 Great home, 10 min walk to Beach
# 3  city scrape      La Jolla: 2 Bedrooms, 1 Bath, 3Blks 2 Ocean
# 4  city scrape               charming, colorful, close to beach
#
#                                          description  \
# 0  This Beautiful Craftsmen house has all the mod...
# 1  Your San Diego hideaway awaits!<br /><br />Pri...
# 2  This 2 bedroom, 2 full bathroom home offers al...
# 3  This is a private entrance cottage detached fr...
# 4  Modern, cozy, artsy, and european in a lush ga...
#
#                                neighborhood_overview  \
# 0  We have the best Neighborhood in San Diego, in...
# 1                                                NaN
# 2                                                NaN
# 3  Tranquility, stately trees, meditative, zen-fu...
# 4  We are in walking distance to Starbucks, Trade...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...       29  ...
# 1  https://a0.muscache.com/pictures/hosting/Hosti...    48669  ...
# 2  https://a0.muscache.com/pictures/76103867/c9b5...   129123  ...
# 3  https://a0.muscache.com/pictures/47035b04-633c...   252692  ...
# 4  https://a0.muscache.com/pictures/84577734/93ca...   302986  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.98                   4.79                4.80
# 1                        5.00                   4.75                4.75
# 2                        4.93                   4.84                4.76
# 3                        4.96                   4.97                4.88
# 4                        4.86                   4.87                4.79
#
#               license instant_bookable calculated_host_listings_count  \
# 0  STR-04545L, 631067                f                              1
# 1  STR-06735L, 631362                f                              2
# 2  STR-05218L, 645110                f                              5
# 3  STR-05706L, 523003                f                              2
# 4  STR-00821L, 520121                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           0
# 2                                           5
# 3                                           1
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            0
# 3                                            1
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.82
# 1                                           0              0.03
# 2                                           0              0.65
# 3                                           0              2.03
# 4                                           0              5.45
#
# [5 rows x 75 columns]
#                  id     scrape_id       host_id  host_listings_count  \
# count  1.284400e+04  1.284400e+04  1.284400e+04         12844.000000
# mean   5.672514e+17  2.024122e+13  1.833473e+08            93.238711
# std    5.112182e+17  0.000000e+00  1.895293e+08           452.048384
# min    6.000000e+00  2.024122e+13  2.900000e+01             1.000000
# 25%    3.830121e+07  2.024122e+13  2.631867e+07             1.000000
# 50%    6.820215e+17  2.024122e+13  9.733012e+07             4.000000
# 75%    1.043521e+18  2.024122e+13  3.463943e+08            24.000000
# max    1.316901e+18  2.024122e+13  6.677896e+08          4660.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               12844.000000                           0.0  12844.000000
# mean                  151.968779                           NaN     32.770594
# std                   719.544324                           NaN      0.064983
# min                     1.000000                           NaN     32.540760
# 25%                     2.000000                           NaN     32.728459
# 50%                     6.000000                           NaN     32.761306
# 75%                    32.000000                           NaN     32.799605
# max                  8110.000000                           NaN     33.101790
#
#           longitude  accommodates     bathrooms  ...  \
# count  12844.000000  12844.000000  11660.000000  ...
# mean    -117.184553      5.077624      1.633148  ...
# std        0.065926      3.344127      1.008138  ...
# min     -117.281629      1.000000      0.000000  ...
# 25%     -117.249550      2.000000      1.000000  ...
# 50%     -117.176466      4.000000      1.000000  ...
# 75%     -117.141330      6.000000      2.000000  ...
# max     -116.936852     16.000000     23.000000  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               10638.000000           10638.000000
# mean                    4.801859               4.888148
# std                     0.318568               0.261686
# min                     1.000000               1.000000
# 25%                     4.750000               4.880000
# 50%                     4.890000               4.960000
# 75%                     4.980000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 10638.000000            10638.000000
# mean                      4.887179                4.844000
# std                       0.275174                0.257678
# min                       1.000000                1.000000
# 25%                       4.880000                4.800000
# 50%                       4.960000                4.920000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count         10638.000000                    12844.000000
# mean              4.719771                       16.601993
# std               0.359766                       30.300673
# min               1.000000                        1.000000
# 25%               4.660000                        1.000000
# 50%               4.800000                        3.000000
# 75%               4.900000                       16.000000
# max               5.000000                      166.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 12844.000000
# mean                                     14.267751
# std                                      27.628015
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                      12.000000
# max                                     166.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  12844.000000
# mean                                       0.969558
# std                                        3.352283
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       23.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 12844.000000       10638.000000
# mean                                      0.020009           1.895018
# std                                       0.411606           2.054475
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.450000
# 50%                                       0.000000           1.410000
# 75%                                       0.000000           2.870000
# max                                      10.000000          53.700000
#
# [8 rows x 40 columns]

# %% [markdown]
# So listing has 12844 rows and 75 columns. A lot of these columns contain listing and host urls and images that are not useful for analysis. We will be dropping them. The calculated_* columns have no information about what they are in the dictionary and we will be dropping them as well.

# %%
calculated_columns = san_diego_listings.columns[san_diego_listings.columns.str.startswith('calculated_')]

## list of fields to be dropped
columns_to_drop = [
    'listing_url','license', 'scrape_id', 'last_scraped',
    'source', 'picture_url', 'host_url', 'host_name', 'host_thumbnail_url',
    'host_picture_url', 'host_since', 'host_location', 'host_has_profile_pic',
    'host_listings_count', 'host_neighbourhood', 'host_verifications','host_about','description',
    'neighborhood_overview', 'calendar_last_scraped','first_review','last_review', 'minimum_nights_avg_ntm','minimum_minimum_nights',
    'maximum_minimum_nights', 'maximum_maximum_nights', 'minimum_maximum_nights', 'maximum_nights_avg_ntm',
    'reviews_per_month'
]
## get all the fields that start with calculated_ and add them to the columns_to_drop list
for i in calculated_columns:
    columns_to_drop.append(i)

## dropping columns that are not needed
san_diego_listings_cleaned = san_diego_listings.drop(columns=columns_to_drop)

# %% [markdown]
# we will now look at missing values and distributions for the remaining columns to analyze it further.

# %%
## looking at how many null values are in the data
print(san_diego_listings_cleaned.isnull().sum())

## looking at the data types for each column
print(san_diego_listings_cleaned.dtypes)
# Out:
# id                                  0
# name                                0
# host_id                             0
# host_response_time               1461
# host_response_rate               1461
# host_acceptance_rate              941
# host_is_superhost                 423
# host_total_listings_count           0
# host_identity_verified              0
# neighbourhood                    4798
# neighbourhood_cleansed              0
# neighbourhood_group_cleansed    12844
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# accommodates                        0
# bathrooms                        1184
# bathrooms_text                      1
# bedrooms                          204
# beds                             1224
# amenities                           0
# price                            1184
# minimum_nights                      0
# maximum_nights                      0
# calendar_updated                12844
# has_availability                   89
# availability_30                     0
# availability_60                     0
# availability_90                     0
# availability_365                    0
# number_of_reviews                   0
# number_of_reviews_ltm               0
# number_of_reviews_l30d              0
# review_scores_rating             2206
# review_scores_accuracy           2206
# review_scores_cleanliness        2206
# review_scores_checkin            2206
# review_scores_communication      2206
# review_scores_location           2206
# review_scores_value              2206
# instant_bookable                    0
# dtype: int64
# id                                int64
# name                             object
# host_id                           int64
# host_response_time               object
# host_response_rate               object
# host_acceptance_rate             object
# host_is_superhost                object
# host_total_listings_count         int64
# host_identity_verified           object
# neighbourhood                    object
# neighbourhood_cleansed           object
# neighbourhood_group_cleansed    float64
# latitude                        float64
# longitude                       float64
# property_type                    object
# room_type                        object
# accommodates                      int64
# bathrooms                       float64
# bathrooms_text                   object
# bedrooms                        float64
# beds                            float64
# amenities                        object
# price                            object
# minimum_nights                    int64
# maximum_nights                    int64
# calendar_updated                float64
# has_availability                 object
# availability_30                   int64
# availability_60                   int64
# availability_90                   int64
# availability_365                  int64
# number_of_reviews                 int64
# number_of_reviews_ltm             int64
# number_of_reviews_l30d            int64
# review_scores_rating            float64
# review_scores_accuracy          float64
# review_scores_cleanliness       float64
# review_scores_checkin           float64
# review_scores_communication     float64
# review_scores_location          float64
# review_scores_value             float64
# instant_bookable                 object
# dtype: object

# %% [markdown]
# neighbourhood_group_cleansed and calender_updated columns have only null values and nothing else and can hence be removed. further neighbourhoood_clensed is a more accurate version of neighbourhood hence the column neighborhood is removed. some of the other columns have a few null values but we will deal with those in a future step by either imputing those values.

# %%
san_diego_listings_cleaned = san_diego_listings_cleaned.drop(columns=['neighbourhood_group_cleansed','calendar_updated','neighbourhood'])

# %% [markdown]
# Some columns in the data frame are of the wrong type. host reponse time is an object (text) and will not be used (hence dropeed),host response rate and acceptance rates will have to converted to integrs, host identity verified will have to converted to boolean (1 for true, 0 for false). We do not look at property type as it is supplied by the lister and we are not dividing listings by property type. we will need to further analyze room_type and likely convert it into a dummy variable. bathroom_text provides no useful information when compared to bathrooms and hence is removed completly. price is of type object likely due to the '$' we will fix this. has availability will need to be converted to a binary instead of text. Finally instant_bookable will also have to converted to a binary column.

# %%
san_diego_listings_cleaned = san_diego_listings_cleaned.drop(columns=['host_response_time','property_type','bathrooms_text'])

# %%
## convert the host_response_rate and host_acceptance_rate columns to numeric
san_diego_listings_cleaned['host_response_rate'] = san_diego_listings_cleaned['host_response_rate'].str.replace('%','').astype(float)
san_diego_listings_cleaned['host_acceptance_rate'] = san_diego_listings_cleaned['host_acceptance_rate'].str.replace('%','').astype(float)

# convert host_identity_verified to a binary value
san_diego_listings_cleaned['host_identity_verified'] = san_diego_listings_cleaned['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)

## convert price to a numeric value
san_diego_listings_cleaned['price'] = san_diego_listings_cleaned['price'].str.replace('$','').str.replace(',','').astype(float)

## has availibity contains some inf values - we will replace them with -1s
san_diego_listings_cleaned['has_availability'] = san_diego_listings_cleaned['has_availability'].replace({np.nan: -1 , np.inf: -1})
san_diego_listings_cleaned['has_availability'] = san_diego_listings_cleaned['has_availability'].replace({'t': 1, 'f': 0}).astype(int)

## conver instant_bookable to a binary value
san_diego_listings_cleaned['instant_bookable'] = san_diego_listings_cleaned['instant_bookable'].replace({'t': 1, 'f': 0}).astype(int)

## convert host_is_superhost to a binary value
san_diego_listings_cleaned['host_is_superhost'] = san_diego_listings_cleaned['host_is_superhost'].replace({np.nan: -1 , np.inf: -1})
san_diego_listings_cleaned['host_is_superhost'] = san_diego_listings_cleaned['host_is_superhost'].replace({'t': 1, 'f': 0}).astype(int)

## convert room_type to a dummy variables then rename them
san_diego_listings_cleaned = pd.get_dummies(san_diego_listings_cleaned, columns=['room_type'], prefix='room_type')
san_diego_listings_cleaned = san_diego_listings_cleaned.rename(columns={'room_type_Entire home/apt': 'room_type_entire_home', 'room_type_Private room': 'room_type_private_room', 'room_type_Shared room': 'room_type_shared_room','room_type_Hotel room':'room_type_hotel_room'})
# Out:
# <ipython-input-8-4189f81c4bd8>:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   san_diego_listings_cleaned['host_identity_verified'] = san_diego_listings_cleaned['host_identity_verified'].replace({'t': 1, 'f': 0}).astype(int)
# <ipython-input-8-4189f81c4bd8>:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   san_diego_listings_cleaned['has_availability'] = san_diego_listings_cleaned['has_availability'].replace({'t': 1, 'f': 0}).astype(int)
# <ipython-input-8-4189f81c4bd8>:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   san_diego_listings_cleaned['instant_bookable'] = san_diego_listings_cleaned['instant_bookable'].replace({'t': 1, 'f': 0}).astype(int)
# <ipython-input-8-4189f81c4bd8>:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   san_diego_listings_cleaned['host_is_superhost'] = san_diego_listings_cleaned['host_is_superhost'].replace({'t': 1, 'f': 0}).astype(int)

# %% [markdown]
# Now with our primary cleaning done on the listings data set, lets look at missing values again

# %%
## look at missing values
print(san_diego_listings_cleaned.isnull().sum())
# Out:
# id                                0
# name                              0
# host_id                           0
# host_response_rate             1461
# host_acceptance_rate            941
# host_is_superhost                 0
# host_total_listings_count         0
# host_identity_verified            0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# accommodates                      0
# bathrooms                      1184
# bedrooms                        204
# beds                           1224
# amenities                         0
# price                          1184
# minimum_nights                    0
# maximum_nights                    0
# has_availability                  0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews                 0
# number_of_reviews_ltm             0
# number_of_reviews_l30d            0
# review_scores_rating           2206
# review_scores_accuracy         2206
# review_scores_cleanliness      2206
# review_scores_checkin          2206
# review_scores_communication    2206
# review_scores_location         2206
# review_scores_value            2206
# instant_bookable                  0
# room_type_entire_home             0
# room_type_hotel_room              0
# room_type_private_room            0
# room_type_shared_room             0
# dtype: int64

# %% [markdown]
# We will be imputing the missing values starting the host response rate and hoset acceptance rates. There are a few ways to do this - we are going to group the listing by what neighborhood they are in, then take a median of each groups response rate and acceptance rate and use that to fill the missing values.

# %%
## group by neighbourhood_clensed, then impute missing values with the median value per group
san_diego_listings_cleaned['host_response_rate'] = san_diego_listings_cleaned.groupby('neighbourhood_cleansed')['host_response_rate'].transform(lambda x: x.fillna(x.median()))
san_diego_listings_cleaned['host_acceptance_rate'] = san_diego_listings_cleaned.groupby('neighbourhood_cleansed')['host_acceptance_rate'].transform(lambda x: x.fillna(x.median()))

## look at these two columns again to make sure we got all the missing values
print(san_diego_listings_cleaned['host_acceptance_rate'].isnull().sum())
print(san_diego_listings_cleaned['host_response_rate'].isnull().sum())
# Out:
# 0
# 0

# %% [markdown]
# next we will impute the missing values in batrooms, bedrooms and beds. We will use a similar approach to before but we will group by accomodates since that is usually a good indicator of how many rooms are in the property and then take a median of each group to fill the missing values.

# %%
columns_to_impute = ['bathrooms','bedrooms','beds']
for col in columns_to_impute:
    san_diego_listings_cleaned[col]=san_diego_listings_cleaned.groupby('accommodates')[col] \
        .transform(lambda x: x.fillna(x.median()))
    print(f"missing values in {col}:{san_diego_listings_cleaned[col].isnull().sum()}")
# Out:
# missing values in bathrooms:0
# missing values in bedrooms:0
# missing values in beds:0

# %% [markdown]
# Next we will impute the missing prices of the listings - the most logical way is to group the listings by neighbourhood since listing prices are usually tied to the neighnourhood and then fill the missing values with the median price of the group they belong to.

# %%
san_diego_listings_cleaned['price'] = san_diego_listings_cleaned.groupby('neighbourhood_cleansed')['price'].transform(lambda x: x.fillna(x.median()))
print(san_diego_listings_cleaned['price'].isnull().sum())
# Out:
# 0

# %% [markdown]
# The last imputations left to do are review_scores_ratings, review_scores_accuracy,review_scores_cleanliness, review_scores_checkin, communication, location and value. sine we do not care of listings with no reviews for this project we drop the records with the missing values.

# %%
## remove the missing values
san_diego_listings_cleaned = san_diego_listings_cleaned.dropna(subset=['review_scores_rating'])

## look at missing value tallies
print(san_diego_listings_cleaned.isnull().sum())
# Out:
# id                             0
# name                           0
# host_id                        0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_total_listings_count      0
# host_identity_verified         0
# neighbourhood_cleansed         0
# latitude                       0
# longitude                      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# amenities                      0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# has_availability               0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# instant_bookable               0
# room_type_entire_home          0
# room_type_hotel_room           0
# room_type_private_room         0
# room_type_shared_room          0
# dtype: int64

# %% [markdown]
# Lets plot a correlatin matrix with the remaining numerical features to see which ones are tighty correlated. We will drop features that are super tighly correlated since they will not add any value to our analysis.

# %%
## following columns are either non numeric or unique identifier, we will exclude them for the correlation matrix
print(san_diego_listings_cleaned.info())
cols_to_exc = ['id','neighbourhood_cleansed','amenities','name','host_id']
cor_matrix_df = san_diego_listings_cleaned.drop(columns= cols_to_exc)
# Compute correlation matrix
corr_matrix = cor_matrix_df.corr()

# Plot the correlation heatmap
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', center=0, linewidths=0.5)

# Title
plt.title("Correlation Matrix of Airbnb Listings (San Diego)")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10638 entries, 0 to 12807
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           10638 non-null  int64
#  1   name                         10638 non-null  object
#  2   host_id                      10638 non-null  int64
#  3   host_response_rate           10638 non-null  float64
#  4   host_acceptance_rate         10638 non-null  float64
#  5   host_is_superhost            10638 non-null  int64
#  6   host_total_listings_count    10638 non-null  int64
#  7   host_identity_verified       10638 non-null  int64
#  8   neighbourhood_cleansed       10638 non-null  object
#  9   latitude                     10638 non-null  float64
#  10  longitude                    10638 non-null  float64
#  11  accommodates                 10638 non-null  int64
#  12  bathrooms                    10638 non-null  float64
#  13  bedrooms                     10638 non-null  float64
#  14  beds                         10638 non-null  float64
#  15  amenities                    10638 non-null  object
#  16  price                        10638 non-null  float64
#  17  minimum_nights               10638 non-null  int64
#  18  maximum_nights               10638 non-null  int64
#  19  has_availability             10638 non-null  int64
#  20  availability_30              10638 non-null  int64
#  21  availability_60              10638 non-null  int64
#  22  availability_90              10638 non-null  int64
#  23  availability_365             10638 non-null  int64
#  24  number_of_reviews            10638 non-null  int64
#  25  number_of_reviews_ltm        10638 non-null  int64
#  26  number_of_reviews_l30d       10638 non-null  int64
#  27  review_scores_rating         10638 non-null  float64
#  28  review_scores_accuracy       10638 non-null  float64
#  29  review_scores_cleanliness    10638 non-null  float64
#  30  review_scores_checkin        10638 non-null  float64
#  31  review_scores_communication  10638 non-null  float64
#  32  review_scores_location       10638 non-null  float64
#  33  review_scores_value          10638 non-null  float64
#  34  instant_bookable             10638 non-null  int64
#  35  room_type_entire_home        10638 non-null  bool
#  36  room_type_hotel_room         10638 non-null  bool
#  37  room_type_private_room       10638 non-null  bool
#  38  room_type_shared_room        10638 non-null  bool
# dtypes: bool(4), float64(15), int64(17), object(3)
# memory usage: 3.0+ MB
# None

# %% [markdown]
# a) availability columns are tightly correlated. Dropping all of them except the availability_365.
#
# b) accommodates, bathrooms, bedrooms, beds are all strongly positively correlated. All of these in some way measure capacity so this is not unusual. Since we will not be
# running any kind of prediction based on these, we will drop the beds column (bedrooms provide sufficient info in this case) and keep the rest.
#
# c) number_of_reviews, number_of_reviews_ltm (last 12 months), number_of_reviews_l30d (last 30 days) are all strongly positively correlated. They all
# measure review volume, just over different time frames. Since we are only going to be looking at recent reviews, we will keep number_of_reviews_ltm.

# %%
## setting columns to drop
correlated_colums = ['availability_30','availability_60','availability_90','beds','number_of_reviews','number_of_reviews_l30d']
san_diego_listings_cleaned = san_diego_listings_cleaned.drop(columns=correlated_colums)

# %% [markdown]
# Now that we have removed super tightly coupled coulums lets look at the statistics of the numeriacal columns in the listings data.

# %%
print(san_diego_listings_cleaned.describe())
print(san_diego_listings_cleaned['price'].describe())
# Out:
#                  id       host_id  host_response_rate  host_acceptance_rate  \
# count  1.063800e+04  1.063800e+04        10638.000000          10638.000000
# mean   4.774175e+17  1.667961e+08           98.453939             91.996334
# std    4.888592e+17  1.790876e+08            8.549459             17.929967
# min    6.000000e+00  2.900000e+01            0.000000              0.000000
# 25%    3.279893e+07  2.395070e+07          100.000000             95.000000
# 50%    5.733670e+17  8.291917e+07          100.000000             99.000000
# 75%    9.349477e+17  2.974525e+08          100.000000            100.000000
# max    1.315611e+18  6.647825e+08          100.000000            100.000000
#
#        host_is_superhost  host_total_listings_count  host_identity_verified  \
# count       10638.000000               10638.000000            10638.000000
# mean            0.517390                  77.838785                0.895187
# std             0.564391                 421.676277                0.306327
# min            -1.000000                   1.000000                0.000000
# 25%             0.000000                   2.000000                1.000000
# 50%             1.000000                   6.000000                1.000000
# 75%             1.000000                  28.000000                1.000000
# max             1.000000                5621.000000                1.000000
#
#            latitude     longitude  accommodates  ...  availability_365  \
# count  10638.000000  10638.000000  10638.000000  ...      10638.000000
# mean      32.770811   -117.185668      5.101805  ...        204.955631
# std        0.063804      0.066528      3.312821  ...        119.511348
# min       32.540760   -117.281629      1.000000  ...          0.000000
# 25%       32.731313   -117.250258      2.000000  ...         89.000000
# 50%       32.761794   -117.182825      4.000000  ...        220.000000
# 75%       32.799660   -117.140110      6.000000  ...        322.000000
# max       33.101790   -116.936852     16.000000  ...        365.000000
#
#        number_of_reviews_ltm  review_scores_rating  review_scores_accuracy  \
# count           10638.000000          10638.000000            10638.000000
# mean               17.717616              4.815047                4.831783
# std                22.442681              0.315070                0.313099
# min                 0.000000              1.000000                1.000000
# 25%                 2.000000              4.770000                4.800000
# 50%                10.000000              4.890000                4.910000
# 75%                28.000000              4.990000                4.990000
# max               663.000000              5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               10638.000000           10638.000000
# mean                    4.801859               4.888148
# std                     0.318568               0.261686
# min                     1.000000               1.000000
# 25%                     4.750000               4.880000
# 50%                     4.890000               4.960000
# 75%                     4.980000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 10638.000000            10638.000000
# mean                      4.887179                4.844000
# std                       0.275174                0.257678
# min                       1.000000                1.000000
# 25%                       4.880000                4.800000
# 50%                       4.960000                4.920000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  instant_bookable
# count         10638.000000      10638.000000
# mean              4.719771          0.369430
# std               0.359766          0.482673
# min               1.000000          0.000000
# 25%               4.660000          0.000000
# 50%               4.800000          0.000000
# 75%               4.900000          1.000000
# max               5.000000          1.000000
#
# [8 rows x 26 columns]
# count    10638.000000
# mean       308.392790
# std        528.001993
# min         26.000000
# 25%        123.000000
# 50%        192.000000
# 75%        350.000000
# max      11998.000000
# Name: price, dtype: float64

# %% [markdown]
# 1)	The host_response_rate has a mean of about 98.45 and a median of 100, suggesting that most hosts reply promptly.
#
# 2)	Similarly, the host_acceptance_rate is very high (mean ~92, median 99), indicating that once contacted, most hosts tend to accept booking requests.
#
# 3)	The host_total_listings_count is highly skewed (median of 6 vs. a mean of nearly 78) with some hosts managing a very large number of listings, indicating the presence of both individual hosts and larger property management companies
#
# 4)	The average listing accommodates about 5 guests (mean 5.1, range from 1 to 16). This suggests a mix of small and larger properties, possibly catering to families or groups.
#
# 5)	availability_365 has a mean of about 205 days, with a median of 220 days. This indicates that many listings are not available year-round—possibly due to seasonal use or host preferences.
#
# 6) The price ranges from 26$ a night to 11998$ a night with a mean of 308$ a night. This is consistent with usual pricing of a 2 bed hotel in san deigo for a night.

# %% [markdown]
# **Distribution and spread Analysis on analytically important numerical columns**
#
# histogram for the follwing columns: Price, Accommodates, Host Total Listings to check for skewness, outliers etc.

# %%
## histogram for price
plt.figure(figsize=(10,6))
sns.histplot(san_diego_listings_cleaned['price'], kde=True)
plt.xticks(np.arange(0, 1200, 100))  # Set x-axis ticks
plt.xlim(0, 1500)  # Set x-axis limits
plt.title('Histogram of Price per night')
plt.show()

## histogram for accommodates
plt.figure(figsize=(10,6))
sns.histplot(san_diego_listings_cleaned['accommodates'], kde=True)
plt.title('Histogram of Accommodates')
plt.show()

## plot the host_total_listings_count, adjusting scale from 1 to 150 for the count
plt.figure(figsize=(10,6))
sns.histplot(san_diego_listings_cleaned['host_total_listings_count'], kde=True)
plt.xticks(np.arange(0, 151, 10))  # Set x-axis ticks
plt.xlim(0, 150)  # Set x-axis limits
plt.title('Histogram of Host Total Listings')
plt.show()

# %% [markdown]
# Price: Most listings cluster at lower price ranges (roughly under $200), and then the tail extends toward higher prices, indicating a handful of more expensive properties (right skewed distribution). Theres a visible peak somewhere around $100 to $150 per night, suggesting that many listings fall into that affordable to mid-range price category. There are clearly outliers here (in the far-right end, really high prices, likely luxury stays) but since we are not really using this to predict anything we will not delete any.
#
# Accommodates: The highest bar is for listings that accommodate 2 guests, followed by 4 guests. This suggests that most of San Diego Airbnb listings cater to couples or small families/groups. As the number of guests increases (6, 8, 10, 12, 14, 16), the count of listings steadily drops. Large-group listings exist but are much less common.
#
# Host_total_listings_count: The vast majority of hosts have relatively few listings (likely in the range of 1–5), and then the distribution extends out to higher numbers with very few hosts managing many listings. This is inline with what we hypothesized earlier – there are likely some management companies with 100s of properties listed under them.

# %% [markdown]
# **Visualizing Analytically important categorical variables**
#
# We will create a bar charts for the following columns: neighbourhood_clensed

# %%
## columns to create bar chart plots for
categorical_cols = ['neighbourhood_cleansed']
## create plot
for col in categorical_cols:
    plt.figure(figsize=(20,10))
    sns.countplot(data=san_diego_listings_cleaned, x=col)
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Certain neighborhoods stand out as hotspots for Airbnb listings, such as Pacific Beach, Mission Bay and North Hills. These areas likely attract more tourists and may be favored due to their proximity to beaches, attractions, or lively environments.
#
# We could further look at bivariate relationship’s b/w some of the columns like price and neighborhood but since our main intention is to look at the sentiments and then look at what features might be contributing to them, bivariate analysis at this point is not required.
#
# Next we will look at the reviews data

# %%
## exploring the reviews data
print(san_diego_reviews.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 839296 entries, 0 to 839295
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     839296 non-null  int64
#  1   id             839296 non-null  int64
#  2   date           839296 non-null  object
#  3   reviewer_id    839296 non-null  int64
#  4   reviewer_name  839294 non-null  object
#  5   comments       839097 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 38.4+ MB
# None

# %% [markdown]
# We do not need id,reviewer_id,reviewer_name so we drop them

# %%
## drop the columns we do not need
san_diego_reviews_cleaned = san_diego_reviews.drop(columns=['id','reviewer_id','reviewer_name'])
print(san_diego_reviews_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 839296 entries, 0 to 839295
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  839296 non-null  int64
#  1   date        839296 non-null  object
#  2   comments    839097 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 19.2+ MB
# None

# %% [markdown]
# date is of type object - we will convert it to date type

# %%
## convert date column to type date
san_diego_reviews_cleaned['date'] = pd.to_datetime(san_diego_reviews_cleaned['date'])
print(san_diego_reviews_cleaned.head())
# Out:
#    listing_id       date                                           comments
# 0       29967 2010-07-09  When I booked our stay in San Diego at Dennis ...
# 1       29967 2010-07-14  This was my first experience with using airbnb...
# 2       29967 2010-07-22  We found the house to be very accommodating--e...
# 3       29967 2010-07-29  As advertised and more. Dennis was very helpfu...
# 4       29967 2010-08-07  We had a great time in San Diego. Denis' house...

# %%
# %pip install langdetect
# %pip install tqdm
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.11/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)

# %% [markdown]
# Since we only want the two latest comments for each listing we will group the records by listing_id and date and the sort them descending by date and the select the first 5 english language comments for each listing.

# %%
from concurrent.futures import ProcessPoolExecutor
from tqdm import tqdm
from langdetect import detect

def detect_language(text):
  try:
    return detect(text)
  except:
    return 'unknown'

with ProcessPoolExecutor() as executor:
  results = list(tqdm(executor.map(detect_language, san_diego_reviews_cleaned['comments']), total=len(san_diego_reviews_cleaned)))

san_diego_reviews_cleaned['language'] = results
# Out:
# 100%|██████████| 839296/839296 [37:15<00:00, 375.47it/s]

# %%
print(san_diego_reviews_cleaned['language'].value_counts())
# Out:
# language
# en         807238
# es           7782
# fr           3714
# de           3698
# ro           2986
# unknown      1785
# zh-cn        1673
# ko           1138
# af           1134
# pt            931
# it            931
# so            926
# tl            747
# ca            571
# nl            483
# cs            372
# pl            346
# no            282
# ja            282
# sw            243
# da            225
# sv            212
# hu            168
# ru            165
# hr            155
# id            154
# cy            144
# zh-tw         127
# vi            114
# tr            111
# sl            105
# et             77
# fi             73
# he             57
# ar             50
# sk             45
# sq             18
# lt             10
# lv              9
# uk              5
# th              3
# bg              3
# el              2
# mk              2
# Name: count, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')

# show available file
# !ls '/content/drive/MyDrive'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '351 Poster Project.pptx'
# '601 Final Project '
# '602 study guide.gdoc'
#  655MachineLearning
#  7ACihh2901h024120261713070102202.gdoc
#  7ACihh2901h024120261713070102202.pdf
# 'AFIT loaner laptops.gsheet'
# 'AFIT loaner laptops.xlsx'
# 'AI in the News Article.gdoc'
#  AyanSengupta_ElevatorPitch.mp4
# 'Ayan Sengupta-NDA-Aug 21.pdf'
# 'Ayan Sengupta - Personal Statement.gdoc'
# "Ayan Sengupta - Personal Statement - sarah's edit.docx"
# 'Behavorial Questions '
#  BIA602FinalProject
# 'BIA Final Project Full Presentation.pptx'
# 'BIA Final Project Slam Deck.gslides'
# 'BIA Final Project Slam Deck.pptx'
# 'Bio 109 SI Worksheet #10-2 (1).gdoc'
# 'Bio 109 SI Worksheet #10-2.docx'
# 'Bio 109 SI Worksheet #10-2.gdoc'
# 'Bio 109 SI Worksheet #7 (2).docx'
# 'Bio 109 SI Worksheet #7 (2).gdoc'
# 'Bio 109 SI Worksheet #8 (1).docx'
# 'Bio 109 SI Worksheet #8 (1).gdoc'
# 'Bio 109 SI Worksheet #8 Answers.docx'
# 'Bio 109 SI Worksheet #8 Answers.gdoc'
# 'Bio 109 SI Worksheet #9.docx'
# 'Bio 109 SI Worksheet #9.gdoc'
# 'blog 1.docx'
# 'CamScanner 04-26-2021 11.12.pdf'
# 'Case #2.gslides'
# 'CD Edits_UMassEDPcoverletter.gdoc'
# 'CDR Presentation.pptx'
# 'citations engin.gdoc'
# 'Class notes.gdoc'
#  CLEAN_Data_hotebookings.xlsx
# 'Colab Notebooks'
# 'Contact Information.gform'
# 'Copy of Alexandra Lee - Personal Statement.gdoc'
# 'Copy of Cv-Amit.gdoc'
# 'Copy of Day 1 Activity: Numerical Target.gdoc'
# 'Copy of Digital Equality.gslides'
# 'Copy of Digital Equality.pptx'
# 'Copy of ECE 325 Practice Exam.gdoc'
# 'Copy of Lab 11 Exceptions_Student.gdoc'
# 'Copy of Lab 12 Interfaces_Student.gdoc'
# 'Copy of Lab 13 Exam Review_STUDENT.gdoc'
# 'Copy of Model Evaluation - Knowledge Exchange.gdoc'
# 'Copy of NP_EX_8_Athena_AyanSengupta_Report_2.xlsx'
# 'CursesWrapper (1).zip (Unzipped Files)'
# 'Digital Equality.pptx'
# 'Document from Ayan Sengupta.pdf'
# 'ECE371 lab 3 Report.gdoc'
# 'ECE 371 Lab Report 2.gdoc'
# 'ECE597SD final presentation and demo '
# 'English writing.gdoc'
# 'eng unit 5.docx'
# 'ER Diagrams to Relational Schemas.gdoc'
#  ethnicolr_classified_data
# 'Final.zip (Unzipped Files)'
#  FPR.pptx
# 'FPR Presentation.odp'
# 'free fall_31495572.gdoc'
# 'FREE FALL LAB REPORT.gdoc'
# 'FY20 UMass Amherst powerpoint template-high res.gslides'
# 'Getting started.pdf'
# 'HBR-debrief-report1(Scenario:B,C,F).gdoc'
# 'HBR Simulator Debrief - Scenario B, C, and F.gdoc'
# ' HBR Simulator Debrief - Scenario D, G, and E.gdoc'
# 'Hotel Bookings & Cancellations.xlsx'
#  hotel_bookings_original.xlsx
# 'How do smart gophers Test _.pptx'
# 'Hw #2 (8)'
#  hw4_code.html.gdoc
#  hyperledgerfab.mp4
#  IMG_0505.HEIC
#  IMG_0507.HEIC
#  IMG-20190227-WA0005.jpg
# 'KOODESIGN case study.gslides'
# 'KOODESIGN notes.gdoc'
# 'Lab 10 Mid-Term 2 Review.gdoc'
# 'lab 3.gdoc'
# 'Lab 4 Report.gdoc'
# 'Lab 8 Arrays.gdoc'
# 'Lab 9 Recursion.gdoc'
# 'lab report (1).docx.gdoc'
# 'Lab report 1.gdoc'
# 'lab report (2).docx.gdoc'
# 'lab report.docx'
# 'lab report.docx.gdoc'
#  M5new.m
# 'Machine Learning for Analytics Exam 1 - Cheat Sheet.gdoc'
# 'MDR Presentation.pdf'
# 'Meemken Pictures '
#  MIDI.gdoc
# 'Monitor Presentation 2024.pdf'
#  name.basics_0.csv
# 'No ID.gdoc'
#  Notability
# 'Note Feb 15, 2019 (3).pdf'
# 'Onboarding Documents Checklist (1).xlsx'
# 'Onboarding Documents Checklist.xlsx'
# 'personal statemnt '
# 'PLATINUM HPL.txt.gdoc'
# ' Practical Model Evaluation.gdoc'
#  Prelab1.docx
#  Prelab1.gdoc
# 'Project1 (1).zip'
#  project1_2.asm
#  Project1.zip
# 'Project1.zip (Unzipped Files)'
# 'Project Management Slides: Group 3.gslides'
#  Resume-2022.docx
#  Resume-2022.pdf
#  resume2023.pdf
# 'Resume and cover letters stuff'
#  resume.docx
#  resume.docx.gdoc
# 'RHSvideointerview (2).mp4'
# 'san_diego_reviews_cleaned (1).csv.gz'
# "SDP'21Check-In6"
# 'SDP 21 ideas.gdoc'
# 'Sources for ethics essay.gdoc'
# 'Sources for Technica Description Paper .gdoc'
# 'Study guide anthro 150.gdoc'
# ' Supervised Segmentation Discussion- AyanSengupta.gdoc'
# 'TANISHA H1B Cap Checklist (1).xls'
# 'TANISHA H1B Cap Checklist.xls'
#  TruthTables.xlsx
# 'Untitled Diagram.html'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document.gdoc'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'User Location Classification Task 5April2025.docx'
# 'Voter Ids.gdoc'
# 'Watch List.gdoc'
# 'web dev'
# 'Welcome to CapGemini.gdoc'
# 'Welcome to CapGemini.pdf'
#  WIN_20221129_12_40_23_Pro.jpg

# %%
# save df as a compressed csv file to drive
san_diego_reviews_cleaned.to_csv('/content/drive/MyDrive/san_diego_reviews_cleaned_trash.csv.gz', index=False, compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-125ea963fb58> in <cell line: 0>()
#       1 # save df as a compressed csv file to drive
# ----> 2 san_diego_reviews_cleaned.to_csv('/content/drive/MyDrive/san_diego_reviews_cleaned.csv.gz', index=False, compression='gzip')
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in save(self)
#     268             )
#     269
# --> 270             self._save()
#     271
#     272     def _save(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     273         if self._need_to_save_header:
#     274             self._save_header()
# --> 275         self._save_body()
#     276
#     277     def _save_header(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     311             if start_i >= end_i:
#     312                 break
# --> 313             self._save_chunk(start_i, end_i)
#     314
#     315     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     322
#     323         ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324         libwriters.write_csv_rows(
#     325             data,
#     326             ix,
#
# writers.pyx in pandas._libs.writers.write_csv_rows()
#
# /usr/lib/python3.11/gzip.py in closed(self)
#     321         return self._buffer.peek(n)
#     322
# --> 323     @property
#     324     def closed(self):
#     325         return self.fileobj is None
#
# KeyboardInterrupt:

# %%
# read the drive saved file into the san_diego_reviews_cleaned
san_diego_reviews_cleaned = pd.read_csv('/content/drive/MyDrive/san_diego_reviews_cleaned (1).csv.gz', compression='gzip')

# %%
print(san_diego_reviews_cleaned.shape)
# Out:
# (839296, 4)

# %%
print(san_diego_reviews_cleaned['language'].value_counts())
# Out:
# language
# en         807238
# es           7782
# fr           3714
# de           3698
# ro           2986
# unknown      1785
# zh-cn        1673
# ko           1138
# af           1134
# pt            931
# it            931
# so            926
# tl            747
# ca            571
# nl            483
# cs            372
# pl            346
# no            282
# ja            282
# sw            243
# da            225
# sv            212
# hu            168
# ru            165
# hr            155
# id            154
# cy            144
# zh-tw         127
# vi            114
# tr            111
# sl            105
# et             77
# fi             73
# he             57
# ar             50
# sk             45
# sq             18
# lt             10
# lv              9
# uk              5
# th              3
# bg              3
# el              2
# mk              2
# Name: count, dtype: int64

# %%
orinal_size = san_diego_reviews_cleaned.shape[0]
print(orinal_size)
# keep only english comments
san_diego_reviews_cleaned = san_diego_reviews_cleaned[san_diego_reviews_cleaned['language'] == 'en']
neww_size = san_diego_reviews_cleaned.shape[0]
print(f"dropeed {orinal_size - neww_size} rows")
# Out:
# 839296
# dropeed 32058 rows

# %%
# Sort by listing_id and date
san_diego_reviews_cleaned = san_diego_reviews_cleaned.sort_values(['listing_id', 'date'], ascending=[True, False])

# Group by listing_id and get the top 5 latest comments
san_diego_reviews_cleaned = san_diego_reviews_cleaned.groupby('listing_id').head(5)

# Reset index if needed
san_diego_reviews_cleaned = san_diego_reviews_cleaned.reset_index(drop=True)

## no of rows atfer clean up
print(san_diego_reviews_cleaned.shape)
# Out:
# (47709, 4)

# %%
# looking at what the data set looks like
print(san_diego_reviews_cleaned.head(100))
# Out:
#     listing_id        date                                           comments  \
# 0            6  2024-10-20  Loved our stay! We were there for a wedding in...
# 1            6  2024-10-13  Absolutely loved this stay!  Right in the midd...
# 2            6  2024-08-18  Sara's place is centrally located in North Par...
# 3            6  2024-08-16  the home was great, it had a very comfy feel t...
# 4            6  2024-08-15  Had an amazing stay at Sarah’s place! She is a...
# ..         ...         ...                                                ...
# 95      182428  2023-07-25  awesome place, close enough to the water. only...
# 96      182428  2023-06-16  Fabulous location. Central to either the beach...
# 97      182428  2023-06-04                      Nice place…close to the beach
# 98      182428  2022-10-03  We very much enjoyed our stay at Luke's place,...
# 99      182504  2024-10-22  I cannot say enough about how much I enjoyed m...
#
#    language
# 0        en
# 1        en
# 2        en
# 3        en
# 4        en
# ..      ...
# 95       en
# 96       en
# 97       en
# 98       en
# 99       en
#
# [100 rows x 4 columns]

# %%
# check how many reviews eacg listing has
print(san_diego_reviews_cleaned['listing_id'].value_counts())
# Out:
# listing_id
# 1292780160643569110    5
# 576112                 5
# 585426                 5
# 585469                 5
# 587471                 5
#                       ..
# 1289167811211550606    1
# 1289208118195601717    1
# 1289225313478300985    1
# 1289240926003624958    1
# 1289484011282663928    1
# Name: count, Length: 10592, dtype: int64

# %% [markdown]
# Some listings do not hace 5 english (or in some cases just do not have 5) reviews which is expected so we will aggreated based on reviews available

# %% [markdown]
# we will be using VADER for our sentiment analysis - lets import the required libraries

# %%
# %pip install vaderSentiment==3.3.2
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# Requirement already satisfied: vaderSentiment==3.3.2 in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from vaderSentiment==3.3.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment==3.3.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment==3.3.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment==3.3.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment==3.3.2) (2025.4.26)

# %% [markdown]
# we will use lang detect to detect languages of the reiews and then convert them to english using googletrans. We will then use VADER to get the sentiment scores for each review and then take the mean of the 5 latest reviews for each listing. We will then merge this with the listings data set on listing_id.

# %%
print(san_diego_reviews_cleaned['language'].value_counts())
# Out:
# language
# en    47709
# Name: count, dtype: int64

# %%
# Filter out rows where 'comments' is missing or empty
san_diego_reviews_cleaned_nonull = san_diego_reviews_cleaned[san_diego_reviews_cleaned['comments'].notnull()]
dropped_rows = san_diego_reviews_cleaned.shape[0] - san_diego_reviews_cleaned_nonull.shape[0]
print(f"Dropped {dropped_rows} rows with missing or empty comments.")

# Reapply sentiment analysis to the filtered dataset
analyzer = SentimentIntensityAnalyzer()
san_diego_reviews_cleaned_nonull['sentiment'] = san_diego_reviews_cleaned_nonull['comments'].apply(lambda review: analyzer.polarity_scores(review)['compound'])

# Check the updated dataset
print(san_diego_reviews_cleaned_nonull.head())
# Out:
# Dropped 0 rows with missing or empty comments.
#    listing_id        date                                           comments  \
# 0           6  2024-10-20  Loved our stay! We were there for a wedding in...
# 1           6  2024-10-13  Absolutely loved this stay!  Right in the midd...
# 2           6  2024-08-18  Sara's place is centrally located in North Par...
# 3           6  2024-08-16  the home was great, it had a very comfy feel t...
# 4           6  2024-08-15  Had an amazing stay at Sarah’s place! She is a...
#
#   language  sentiment
# 0       en     0.9600
# 1       en     0.9536
# 2       en     0.9550
# 3       en     0.8122
# 4       en     0.9622

# %% [markdown]
# we now have the sentimenet scores (ranging from 0 to 1) for each comment - we will now aggrete this by listing ID to get an idea of average sentiment for the listing.
#
# We will now scaled it to be between 1 to 5 for better readability

# %%
san_diego_reviews_cleaned_nonull.head()
# Out:
#    listing_id        date                                           comments  \
# 0           6  2024-10-20  Loved our stay! We were there for a wedding in...
# 1           6  2024-10-13  Absolutely loved this stay!  Right in the midd...
# 2           6  2024-08-18  Sara's place is centrally located in North Par...
# 3           6  2024-08-16  the home was great, it had a very comfy feel t...
# 4           6  2024-08-15  Had an amazing stay at Sarah’s place! She is a...
#
#   language  sentiment
# 0       en     0.9600
# 1       en     0.9536
# 2       en     0.9550
# 3       en     0.8122
# 4       en     0.9622

# %%
import numpy as np
from sklearn.preprocessing import KBinsDiscretizer

# %%
# Initialize the discretizer
kbd = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='kmeans')
kbd.fit(san_diego_reviews_cleaned_nonull[['sentiment']])

reviews_binned = kbd.transform(san_diego_reviews_cleaned_nonull[['sentiment']]) +1
san_diego_reviews_cleaned_nonull['sentiment_scaled'] = reviews_binned

# display the results
print(san_diego_reviews_cleaned_nonull.head())
# Out:
#    listing_id        date                                           comments  \
# 0           6  2024-10-20  Loved our stay! We were there for a wedding in...
# 1           6  2024-10-13  Absolutely loved this stay!  Right in the midd...
# 2           6  2024-08-18  Sara's place is centrally located in North Par...
# 3           6  2024-08-16  the home was great, it had a very comfy feel t...
# 4           6  2024-08-15  Had an amazing stay at Sarah’s place! She is a...
#
#   language  sentiment  sentiment_scaled
# 0       en     0.9600               5.0
# 1       en     0.9536               5.0
# 2       en     0.9550               5.0
# 3       en     0.8122               5.0
# 4       en     0.9622               5.0

# %%
# lets take a look at a histogram of the distribution of data

# %% [markdown]
# we will now aggreate these scaled_scores by listing id so that there is only 1 record per listing id

# %%
# drop sentiment and language cols
san_diego_reviews_cleaned_nonull = san_diego_reviews_cleaned_nonull.drop(columns=['language','sentiment'])

# %%
# group by sentiment scaled score, combine comments
grouped_comments = san_diego_reviews_cleaned_nonull.groupby('sentiment_scaled')['comments'].apply(lambda x: ' '.join(x))
# Out:
# Unfortunately wouldn't recommend! It's not quiet at all - you can hear everything in happening in the main house. This space shares a wall near their daughter's bedroom. I heard loud talking and doors opening and closing at 4:30am despite being told their daughter wouldn't be home during my stay. The parking is also not plentiful as described and is difficult with very limited spots, especially being on a hill and having heavy luggage to bring up and down. Not sure why parking in front of the neighbor's place was restricted - would've loved reasoning behind that. The shower is also extremely small. I could barely lift an arm without knocking over the soap, etc. This was hidden well in the one bathroom photo shown. Belinda was very responsive and the bed was comfy, but I couldn't get a good night's sleep with the shared walls and noises coming from the main house. Michael’s home worked out well for my group. It’s a short walk to pacific beach surfing area (10 min) and a bit longer for the swimming area/near the restaurants/bars (~20 min). It’s a quiet residential area, but still easy to get to bars, restaurants and the beach. A couple things to know: There is no AC and the fans are pretty weak; there was no hand soap in the bathroom but we were able to snag the kitchen soap; there was shampoo and body wash but no conditioner. The beach chairs and towels provided were a big help, as was the complex’s washer and dryer. It’s not a glamorous place but the price is right especially if you’re not planning to spend a ton of time at home. Despite the host being very nice and welcoming, this place was overpriced, dirty, and a lot of the amenities listed don't actually exist.  When I moved into the place, there was a permeating smell from the sink.  It turned out the disposal had been clogged with rotten food and not flushed through.  The utensil and bowls were mostly dirty, and after walking on the floor around the apartment, my feet would get black after just a minute of walking.  The host did a good job of fixing the floor, but it really shouldn't have been an issue to begin with.  The listing promised free breakfast provided each morning and gym access.  Although the gym was closed due to COVID, I still expected the info to be up to date.  Breakfast was never a thing, and it's a complete lie its on the listing.  The first week and a half I was there, the A/C was broken (eventually it was fixed), which is a little crazy I'm still paying such a steep price to live in a burning hot apartment.  Overall, $3800/mo was a steep price to pay for the sub-par quality.  I was expecting a fully maintained, above-average place, compared to the nearby listing prices, and I was very disappointed.  Had this been $1000 cheaper, I would be close to fully satisfied, but I feel I got a terrible value for my money. No AC?!!?? What in the actual Second time staying here and will stay again. The view never gets old. Enjoy walking along the boardwalk. Lots of shops and restaurants close by. I was here for 8 days. The ac unit only blows on one setting which is low. The room will still get cool so don’t worry. The bed is in a tight spot so getting in and out of the bed was a squeeze. Be prepared to use your own person streaming account as well. Upstairs guest/tenants where a little noisy not too much besides the vacuum going early in the morning dogs barking and arguing besides that it’s decent spot to stay. Convenient location.  Very walkable. <br/>With no AC and hot days the windows need to be open. You will hear the loud planes and the noisy birds.  Car alarms. Etc.<br/>The unit is good sized. Albeit dated. The massive mirrors are something!  The beds were comfortable and clean.  <br/>Bathrooms only upstairs is a little annoying.  Parking is very, very tight. Would not recommend for mini vans.  <br/>Bathrooms need some work. More hooks for suits and towels. <br/>The items in the beach box came in handy for the day we made it to the beach. <br/>We were also  ...

# %% [markdown]
# We will now run topic modeling on the comennts that have certain scores and save them

# %%
# topic modelling by sentiment scre scaled
# !pip install --upgrade numpy==1.25.2
# !pip install --upgrade scipy==1.11.2
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF, TruncatedSVD
# Out:
# Requirement already satisfied: numpy==1.25.2 in /usr/local/lib/python3.11/dist-packages (1.25.2)
# Requirement already satisfied: scipy==1.11.2 in /usr/local/lib/python3.11/dist-packages (1.11.2)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from scipy==1.11.2) (1.25.2)

# %%
# Download required NLTK data
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# aggregate sentiment_scale score by listing id
# san_diego_reviews_cleaned_nonull = san_diego_reviews_cleaned_nonull.groupby('listing_id')['sentiment_scaled'].mean().reset_index()
# san_diego_reviews_cleaned_nonull['sentiment_scaled'] = san_diego_reviews_cleaned_nonull['sentiment_scaled'].round()

# %%
# print(san_diego_reviews_cleaned_nonull.shape[0])
# print(san_diego_reviews_cleaned_nonull.head())
# print(san_diego_reviews_cleaned_nonull['sentiment_scaled'].value_counts())

# %% [markdown]
# Now that we have the sentiment scores for all the availale ids we will join these back with the other data set to finally run our analysis

# %%
# # combine san_diego_listings_cleaned and sandiego_reviews data on ID and listing ID - right join
# san_diego_combined = san_diego_listings_cleaned.merge(san_diego_reviews_cleaned_nonull, left_on='id', right_on='listing_id', how='right')

# %%
# look at the size of the new df and the head
# print(san_diego_combined.shape)
# print(san_diego_combined.head())

# %% [markdown]
# Test comment
